# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
p1 = 0.5
delta_p = 0.5
p2 = p1*delta_p
p3 = p2*delta_p
p4 = p3*delta_p

p3_mat = [[p1, p2, p3, p3, p4, p4, p4, p4],
          [p2, p1, p3, p3, p4, p4, p4, p4],
          [p3, p3, p1, p2, p4, p4, p4, p4],
          [p3, p3, p2, p1, p4, p4, p4, p4],
          [p4, p4, p4, p4, p1, p2, p3, p3],
          [p4, p4, p4, p4, p2, p1, p3, p3],
          [p4, p4, p4, p4, p3, p3, p1, p2],
          [p4, p4, p4, p4, p3, p3, p2, p1]]

#Average of merged p3 and p4 densities
new_p3 = (2*p3 + 4*p4)/6
p2_mat = [[p1, p2, new_p3, new_p3, new_p3, new_p3, new_p3, new_p3],
          [p2, p1, new_p3, new_p3, new_p3, new_p3, new_p3, new_p3],
          [new_p3, new_p3, p1, p2, new_p3, new_p3, new_p3, new_p3],
          [new_p3, new_p3, p2, p1, new_p3, new_p3, new_p3, new_p3],
          [new_p3, new_p3, new_p3, new_p3, p1, p2, new_p3, new_p3],
          [new_p3, new_p3, new_p3, new_p3, p2, p1, new_p3, new_p3],
          [new_p3, new_p3, new_p3, new_p3, new_p3, new_p3, p1, p2],
          [new_p3, new_p3, new_p3, new_p3, new_p3, new_p3, p2, p1]]

#Average of merged p2 and p3 densities
new_p2 = (p2 + 6*new_p3)/7
p1_mat = [[p1, new_p2, new_p2, new_p2, new_p2, new_p2, new_p2, new_p2],
          [new_p2, p1, new_p2, new_p2, new_p2, new_p2, new_p2, new_p2],
          [new_p2, new_p2, p1, new_p2, new_p2, new_p2, new_p2, new_p2],
          [new_p2, new_p2, new_p2, p1, new_p2, new_p2, new_p2, new_p2],
          [new_p2, new_p2, new_p2, new_p2, p1, new_p2, new_p2, new_p2],
          [new_p2, new_p2, new_p2, new_p2, new_p2, p1, new_p2, new_p2],
          [new_p2, new_p2, new_p2, new_p2, new_p2, new_p2, p1, new_p2],
          [new_p2, new_p2, new_p2, new_p2, new_p2, new_p2, new_p2, p1]]

# %%
import pickle
from score_plotting_utils import create_fig_path
experiment_path = 'results/SBM/SBM_MC_tanh_nnodes50_p10.5_delta_p0.5_min_weight0_bin_directedTrue_wei_directedFalse/'
fig_path = create_fig_path(experiment_path)
network_data_path = experiment_path + 'network_data/'
nets = pickle.load(open(network_data_path + 'nets.pickle', 'rb'))

# %%
fig, ax = plt.subplots(figsize=(3, 3))
ax.imshow(p1_mat, cmap = sns.color_palette("PuBu", as_cmap=True))
ax.axis('off')
ax.set(xticklabels=[], yticklabels=[])
ax.set(xticks=[], yticks=[])
plt.savefig(fig_path + '/p1.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(3, 3))
ax.imshow(nets['1'][0], cmap = sns.color_palette("PuBu", as_cmap=True))
ax.axis('off')
ax.set(xticklabels=[], yticklabels=[])
ax.set(xticks=[], yticks=[])
plt.savefig(fig_path + '/net1.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(3, 3))
ax.imshow(p2_mat, cmap = sns.color_palette("GnBu", as_cmap=True))
ax.axis('off')
ax.set(xticklabels=[], yticklabels=[])
ax.set(xticks=[], yticks=[])
plt.savefig(fig_path + '/p2.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(3, 3))
ax.imshow(nets['2'][0], cmap = sns.color_palette("GnBu", as_cmap=True))
ax.axis('off')
ax.set(xticklabels=[], yticklabels=[])
ax.set(xticks=[], yticks=[])
plt.savefig(fig_path + '/net2.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(3, 3))
ax.imshow(p3_mat, cmap = sns.color_palette("PuRd", as_cmap=True))
ax.axis('off')
ax.set(xticklabels=[], yticklabels=[])
ax.set(xticks=[], yticks=[])
plt.savefig(fig_path + '/p3.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(3, 3))
ax.imshow(nets['3'][0], cmap = sns.color_palette("PuRd", as_cmap=True))
ax.axis('off')
ax.set(xticklabels=[], yticklabels=[])
ax.set(xticks=[], yticks=[])
plt.savefig(fig_path + '/net3.png', dpi=300, bbox_inches='tight')
